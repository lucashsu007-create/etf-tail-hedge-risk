# %% [markdown]
# # Literature Map
#
# Track each paper using: question, data, method, finding, blind spot, and project relevance.

# %%
import pandas as pd

papers = [
    {'paper': 'Madhavan & Sobczyk (2016)', 'area': 'ETF pricing', 'blind_spot': 'Not market-maker hedge-error tails'},
    {'paper': 'Box et al. (2021)', 'area': 'Intraday ETF arbitrage', 'blind_spot': 'Not liquidity-conditioned hedge-error EVT'},
    {'paper': 'Nolde & Zhou (2021)', 'area': 'EVT financial risk', 'blind_spot': 'General risk framework, not ETF microstructure-specific'},
]
pd.DataFrame(papers)
