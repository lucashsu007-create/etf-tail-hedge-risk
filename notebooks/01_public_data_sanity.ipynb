# %% [markdown]
# # Public Data Sanity Check
#
# Use this notebook only for pipeline testing with public or toy data. Do not make research claims from this notebook.

# %%
# TODO: load temporary public CSVs here
# Expected columns: timestamp, ticker, price or bid/ask
print('Add public-data sanity checks here.')
